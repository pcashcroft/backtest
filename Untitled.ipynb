# %%
import os, sys
print("cwd:", os.getcwd())
print("python:", sys.executable)
# Out:
# cwd: C:\Users\pcash\OneDrive\Backtest
# python: C:\Users\pcash\anaconda3\envs\backtest\python.exe

# %%
from sanity_module import add
add(2, 3)
# Out:
# 5
